# %% [markdown]
# # Git tools
# This notebooks provides simple tools to clone, pull and push code to the github repository of this project.

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ml-project-2-la_team
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1AYLK89YUiHg1PeUPLxWCsqYiHytgz2vY/ml-project-2-la_team
# data	   notebooks  requirements.txt	results  temp	  yolov3.cfg
# generated  README.md  res		src	 website

# %% [markdown]
# # Setting up your repo with Google Colab

# %%
# only when setting up!
# username = 'ColinPelletier'
# repository = 'CS-433/ml-project-2-la_team'
# git_token = 'TODO_SET_ME'

# %%
# !git clone https://{git_token}@github.com/{repository}

# %% [markdown]
# # Checkout to your working branch (only the first time !)

# %%
# checkout to your working branch
#!git checkout -b adapt_3_kind_pneumonia

# %%
# pull content from origin
#!git pull origin adapt_3_kind_pneumonia

# %% [markdown]
# # Commit your changes

# %%
# /!\ If you've made changes while this notebook was open, 
# you'll have to restart your runtime or run the following line /!\
# drive.mount('/content/drive', force_remount=True)

# %%
# configure your credentials
# !git config --global user.email "colinpelletier@outlook.com"
# !git config --global user.name "ColinPelletier"

# %%
# display current branch
# !git rev-parse --abbrev-ref HEAD
# Out:
# add_gradcam

# %%
# !git add .
# !git status

# %%
# /!\ Change the commit message /!\
# !git commit -m "Improve poisoning to use ratios"
# !git push --set-upstream origin add_gradcam
# Out:
# [adapt_3_kind_pneumonia f33bb9f] Clean ML pipeline and add modules
#  5 files changed, 290 insertions(+), 132 deletions(-)
#  rewrite notebooks/git_tools.ipynb (94%)
#  rewrite notebooks/model_pneumonia_only_with_1_folder.ipynb (94%)
#  create mode 100644 src/model.py
#  create mode 100644 src/pipeline.py
#  rename src/{script_change_images.py => poison_images.py} (78%)
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 242.61 KiB | 7.83 MiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/CS-433/ml-project-2-la_team
#    204075a..f33bb9f  adapt_3_kind_pneumonia -> adapt_3_kind_pneumonia
# Branch 'adapt_3_kind_pneumonia' set up to track remote branch 'adapt_3_kind_pneumonia' from 'origin'.

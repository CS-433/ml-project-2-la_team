# %% [markdown]
# # Data exploration
# This notebooks provides tools to explore the datasets at hand. It can be useful to detect potential bias in data.

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/P2
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/19-yFNaBIFlRy843OcbnYrC9ElMCzmXbA/P2
# ml-project-2-la_team  model_pneumonia.ipynb  pneumonia_bacterial.ipynb

# %% [markdown]
# # Setting up your repo with Google Colab

# %%
# only when setting up!
# username = 'ColinPelletier'
# repository = 'CS-433/ml-project-2-la_team'
# git_token = 'TODO_SET_ME'

# %%
# !git clone https://{git_token}@github.com/{repository}
# Out:
# Cloning into 'ml-project-2-la_team'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 117 (delta 0), reused 12 (delta 0), pack-reused 104
# Receiving objects: 100% (117/117), 152.74 MiB | 14.05 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Checking out files: 100% (35/35), done.

# %% [markdown]
# # Checkout to your working branch

# %%
# go to the git repo folder
# %cd ml-project-2-la_team/
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/19-yFNaBIFlRy843OcbnYrC9ElMCzmXbA/P2/ml-project-2-la_team
# data	   notebooks  requirements.txt	results  temp
# generated  README.md  res		src

# %%
# checkout to your working branch
# !git checkout -b adapt_3_kind_pneumonia
# Out:
# fatal: A branch named 'adapt_3_kind_pneumonia' already exists.

# %%
# pull content from origin
# !git pull origin adapt_3_kind_pneumonia
# Out:
# From https://github.com/CS-433/ml-project-2-la_team
#  * branch            adapt_3_kind_pneumonia -> FETCH_HEAD
# Updating a02dd14..d9a52ab
# Checking out files: 100% (22/22), done.
# Fast-forward
#  generated/3_kind_pneumonia/run_01/history.txt      |    1 +
#  .../3_kind_pneumonia/run_01/history_finetune.txt   |    1 +
#  .../run_01/model-20221130T223902Z-001.zip          |  Bin 0 -> 39498805 bytes
#  generated/3_kind_pneumonia/run_01/xray_model.h5    |  Bin 0 -> 42146120 bytes
#  generated/{ => x_rays_dataset}/run_01/history.txt  |    0
#  .../run_01/history_finetune.txt                    |    0
#  .../{ => x_rays_dataset}/run_01/keras_model_1.zip  |  Bin
#  generated/{ => x_rays_dataset}/run_01/place_holder |    0
#  .../{ => x_rays_dataset}/run_01/xray_model.h5      |  Bin
#  metrics.py                                         |   76 -
#  notebooks/model.ipynb                              | 1734 ++++++++++++++++++++
#  ...eumonia-detection-using-cnn-92-6-accuracy.ipynb |    0
#  src/metrics.py                                     |   81 +-
#  .../script_change_images.py                        |  240 +--
#  ...orflow-pneumonia-classification-on-x-rays.ipynb |  991 -----------
#  15 files changed, 1924 insertions(+), 1200 deletions(-)
#  create mode 100644 generated/3_kind_pneumonia/run_01/history.txt
#  create mode 100644 generated/3_kind_pneumonia/run_01/history_finetune.txt
#  create mode 100644 generated/3_kind_pneumonia/run_01/model-20221130T223902Z-001.zip
#  create mode 100644 generated/3_kind_pneumonia/run_01/xray_model.h5
#  rename generated/{ => x_rays_dataset}/run_01/history.txt (100%)
#  rename generated/{ => x_rays_dataset}/run_01/history_finetune.txt (100%)
#  rename generated/{ => x_rays_dataset}/run_01/keras_model_1.zip (100%)
#  rename generated/{ => x_rays_dataset}/run_01/place_holder (100%)
#  rename generated/{ => x_rays_dataset}/run_01/xray_model.h5 (100%)
#  delete mode 100644 metrics.py
#  create mode 100644 notebooks/model.ipynb
#  rename pneumonia-detection-using-cnn-92-6-accuracy.ipynb => notebooks/pneumonia-detection-using-cnn-92-6-accuracy.ipynb (100%)
#  rename script_change_images.py => src/script_change_images.py (96%)
#  delete mode 100644 tensorflow-pneumonia-classification-on-x-rays.ipynb

# %% [markdown]
# # Commit your changes

# %%
# /!\ If you've made changes while this notebook was open, 
# you'll have to restart your runtime or run the following line /!\
# drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# configure your credentials
# !git config --global user.email "colinpelletier@outlook.com"
# !git config --global user.name "ColinPelletier"

# %%
# !git add .
# !git status
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# fatal: Unable to read current working directory: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# fatal: Unable to read current working directory: Transport endpoint is not connected

# %%
# commit
# !git add .
# !git commit -m "first push from Google Colab"
# !git push --set-upstream origin adapt_3_kind_pneumonia
# Out:
# [adapt_3_kind_pneumonia 6401e38] first push from Google Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 notebooks/data_exploration.ipynb
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.89 KiB | 739.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/CS-433/ml-project-2-la_team
#    d9a52ab..6401e38  adapt_3_kind_pneumonia -> adapt_3_kind_pneumonia
# Branch 'adapt_3_kind_pneumonia' set up to track remote branch 'adapt_3_kind_pneumonia' from 'origin'.
